# %%
import os
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from tqdm import tqdm
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import warnings

warnings.filterwarnings("ignore")


def cosine_similarity(vec_a, vec_b, eps=1e-9):
    dot = np.dot(vec_a, vec_b)
    norm_a = np.linalg.norm(vec_a)
    norm_b = np.linalg.norm(vec_b)
    return dot / ((norm_a * norm_b) + eps)


def load_and_merge_numeric_features(file_list, merge_on='id'):
    base_df = pd.read_csv(file_list[0], sep='\t')
    for path in file_list[1:]:
        df_next = pd.read_csv(path, sep='\t')
        base_df = pd.merge(base_df, df_next, on=merge_on, how='inner')
    base_df.set_index(merge_on, inplace=True)
    return base_df

def normalize_features(df):
    scaler = StandardScaler()
    return pd.DataFrame(scaler.fit_transform(df), index=df.index, columns=df.columns)

class Music4AllOnionDataset(Dataset):
    def __init__(self, feature_df, label_df=None, transform=None):
        self.transform = transform
        feature_df = feature_df.sort_index()
        self.feature_df = feature_df

        if label_df is not None:
            label_df = label_df.sort_index()
            common_idx = feature_df.index.intersection(label_df.index)
            self.feature_df = feature_df.loc[common_idx]
            self.label_df = label_df.loc[common_idx]
            self.has_labels = True
        else:
            self.label_df = None
            self.has_labels = False

        self.feature_data = self.feature_df.values.astype(np.float32)
        if self.transform:
            self.feature_data = self.transform(self.feature_data)

    def __len__(self):
        return len(self.feature_data)

    def __getitem__(self, idx):
        x = self.feature_data[idx]
        x = torch.tensor(x, dtype=torch.float32)

        if self.has_labels:
            y_val = self.label_df.iloc[idx].values
            y_val = torch.tensor(y_val, dtype=torch.long)
            return x, y_val
        else:
            return x

class MKGCN(nn.Module):
    def __init__(self, input_dim, latent_dim=128):
        super(MKGCN, self).__init__()
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, 512),
            nn.BatchNorm1d(512),
            nn.LeakyReLU(),
            nn.Dropout(0.3),
            nn.Linear(512, 256),
            nn.BatchNorm1d(256),
            nn.LeakyReLU(),
            nn.Dropout(0.3),
            nn.Linear(256, latent_dim)
        )
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, 256),
            nn.BatchNorm1d(256),
            nn.LeakyReLU(),
            nn.Dropout(0.3),
            nn.Linear(256, 512),
            nn.BatchNorm1d(512),
            nn.LeakyReLU(),
            nn.Dropout(0.3),
            nn.Linear(512, input_dim)
        )

    def forward(self, x, reconstruct=False):
        z = self.encoder(x)
        if reconstruct:
            return self.decoder(z)
        return z

class FineTuneClassifier(nn.Module):
    def __init__(self, mkgcn, latent_dim, num_classes):
        super(FineTuneClassifier, self).__init__()
        self.mkgcn = mkgcn
        for param in self.mkgcn.encoder.parameters():
            param.requires_grad = False  

        self.classifier = nn.Sequential(
            nn.Linear(latent_dim, 64),
            nn.LeakyReLU(),
            nn.Linear(64, num_classes)
        )

    def forward(self, x):
        with torch.no_grad():
            z = self.mkgcn.encoder(x)  
        logits = self.classifier(z)
        return logits

def train_mkgcn(model, dataloader, num_epochs=50, lr=1e-3, patience=5, device='cuda'):
    model.to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr)
    criterion = nn.MSELoss()
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=3)

    best_loss = float('inf')
    patience_counter = 0
    best_model_state = None

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for x, _ in dataloader:
            x = x.to(device)
            optimizer.zero_grad()
            x_recon = model(x, reconstruct=True)
            loss = criterion(x_recon, x)  
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        avg_loss = running_loss / len(dataloader)
        print(f"[Epoch {epoch+1}/{num_epochs}] Loss: {avg_loss:.4f}")

        scheduler.step(avg_loss)

        if avg_loss < best_loss:
            best_loss = avg_loss
            patience_counter = 0
            best_model_state = model.state_dict()
        else:
            patience_counter += 1

        if patience_counter >= patience:
            print(f"Early stopping triggered at epoch {epoch+1}")
            break

    if best_model_state is not None:
        model.load_state_dict(best_model_state)


def train_classifier(
    model, dataloader, num_epochs=20, lr=1e-3, patience=5, device='cuda'
):
    model.to(device)
    optimizer = optim.Adam(model.classifier.parameters(), lr=lr)
    criterion = nn.CrossEntropyLoss()
    best_loss = float("inf")
    patience_counter = 0
    best_model_state = None

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for x, y in dataloader:
            x, y = x.to(device), y.to(device)
            optimizer.zero_grad()
            logits = model(x)
            loss = criterion(logits, y.squeeze().long())
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

        avg_loss = running_loss / len(dataloader)
        print(f"[Classifier Epoch {epoch+1}/{num_epochs}] Loss: {avg_loss:.4f}")

        if avg_loss < best_loss:
            best_loss = avg_loss
            patience_counter = 0
            best_model_state = model.state_dict()
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print(f"Early stopping triggered at epoch {epoch+1}")
                break

    if best_model_state is not None:
        model.load_state_dict(best_model_state)

def compute_all_embeddings(dataset, model, device='cuda'):
    model.eval()
    all_embeddings = []

    for i in range(len(dataset)):
        item = dataset[i]
        x = item[0] if isinstance(item, tuple) else item
        x = x.unsqueeze(0).to(device)
        with torch.no_grad():
            z = model(x)
        z_np = z.cpu().numpy().flatten()
        all_embeddings.append(z_np)

    embeddings = np.vstack(all_embeddings)
    return embeddings

def build_recommendation_matrix(embeddings, topK=10):
    N = len(embeddings)
    rec_matrix = np.zeros((N, N), dtype=np.float32)

    for i in tqdm(range(N), desc="Building Recs"):
        vec_i = embeddings[i]
        sims = [cosine_similarity(vec_i, embeddings[j]) for j in range(N)]
        sims = np.array(sims)
        sims[i] = -1e9
        topk_idx = sims.argsort()[::-1][:topK]
        topk_vals = sims[topk_idx]
        rec_matrix[i, topk_idx] = topk_vals

    return rec_matrix

device = "cuda" if torch.cuda.is_available() else "cpu"

numeric_files = [
        "id_blf_correlation_mmsr.tsv",
        "id_blf_deltaspectral_mmsr.tsv",
        "id_blf_logfluc_mmsr.tsv",
        "id_blf_spectral_mmsr.tsv",
        "id_blf_spectralcontrast_mmsr.tsv",
        "id_blf_vardeltaspectral_mmsr.tsv",
        "id_incp_mmsr.tsv",
        "id_ivec256_mmsr.tsv",
        "id_ivec512_mmsr.tsv",
        "id_ivec1024_mmsr.tsv",
        "id_lyrics_tf-idf_mmsr.tsv",
        "id_lyrics_word2vec_mmsr.tsv",
        "id_lyrics_bert_mmsr.tsv",
        "id_mfcc_bow_mmsr.tsv",
        "id_mfcc_stats_mmsr.tsv",
        "id_musicnn_mmsr.tsv",
        "id_resnet_mmsr.tsv",
        "id_vgg19_mmsr.tsv",
        "id_total_listens.tsv"
]

fused_df = load_and_merge_numeric_features(numeric_files, merge_on='id')
fused_df_normalized = normalize_features(fused_df)

labels_path = "id_genres_mmsr.tsv"
if os.path.exists(labels_path):
        labels_df = pd.read_csv(labels_path, sep='\t').set_index('id')
        unique_genres = labels_df['genre'].unique()
        genre_to_idx = {g: i for i, g in enumerate(unique_genres)}
        labels_df['genre_id'] = labels_df['genre'].map(genre_to_idx)
        final_labels_df = labels_df[['genre_id']]
else:
    final_labels_df = None

feature_train, feature_test, label_train, label_test = train_test_split(
        fused_df_normalized, final_labels_df, test_size=0.2, random_state=42
)

train_dataset = Music4AllOnionDataset(feature_train, label_train)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
    
test_dataset = Music4AllOnionDataset(feature_test, label_test)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

input_dim = fused_df_normalized.shape[1]
latent_dim = 128

mkgcn_model = MKGCN(input_dim, latent_dim=latent_dim)
train_mkgcn(mkgcn_model, train_loader, num_epochs=250, lr=1e-3, patience=150, device=device)

if final_labels_df is not None:
    num_classes = len(np.unique(final_labels_df['genre_id']))
    classifier_model = FineTuneClassifier(mkgcn_model, latent_dim, num_classes)
    train_classifier(classifier_model, train_loader, num_epochs=250, patience=100, lr=1e-3, device=device)

full_dataset = Music4AllOnionDataset(fused_df_normalized)
embeddings = compute_all_embeddings(full_dataset, mkgcn_model, device=device)
rec_matrix = build_recommendation_matrix(embeddings, topK=10)
np.savetxt("recs_mkgcn_10.csv", rec_matrix, delimiter="\t")
# Out:
# [Epoch 1/250] Loss: 0.8623
# [Epoch 2/250] Loss: 0.7829
# [Epoch 3/250] Loss: 0.7645
# [Epoch 4/250] Loss: 0.7533
# [Epoch 5/250] Loss: 0.7460
# [Epoch 6/250] Loss: 0.7409
# [Epoch 7/250] Loss: 0.7329
# [Epoch 8/250] Loss: 0.7265
# [Epoch 9/250] Loss: 0.7205
# [Epoch 10/250] Loss: 0.7190
# [Epoch 11/250] Loss: 0.7138
# [Epoch 12/250] Loss: 0.7107
# [Epoch 13/250] Loss: 0.7059
# [Epoch 14/250] Loss: 0.7044
# [Epoch 15/250] Loss: 0.7030
# [Epoch 16/250] Loss: 0.6994
# [Epoch 17/250] Loss: 0.6983
# [Epoch 18/250] Loss: 0.6973
# [Epoch 19/250] Loss: 0.6938
# [Epoch 20/250] Loss: 0.6922
# [Epoch 21/250] Loss: 0.6897
# [Epoch 22/250] Loss: 0.6862
# [Epoch 23/250] Loss: 0.6866
# [Epoch 24/250] Loss: 0.6835
# [Epoch 25/250] Loss: 0.6803
# [Epoch 26/250] Loss: 0.6799
# [Epoch 27/250] Loss: 0.6812
# [Epoch 28/250] Loss: 0.6777
# [Epoch 29/250] Loss: 0.6770
# [Epoch 30/250] Loss: 0.6760
# [Epoch 31/250] Loss: 0.6759
# [Epoch 32/250] Loss: 0.6732
# [Epoch 33/250] Loss: 0.6723
# [Epoch 34/250] Loss: 0.6710
# [Epoch 35/250] Loss: 0.6721
# [Epoch 36/250] Loss: 0.6698
# [Epoch 37/250] Loss: 0.6683
# [Epoch 38/250] Loss: 0.6687
# [Epoch 39/250] Loss: 0.6677
# [Epoch 40/250] Loss: 0.6665
# [Epoch 41/250] Loss: 0.6672
# [Epoch 42/250] Loss: 0.6641
# [Epoch 43/250] Loss: 0.6637
# [Epoch 44/250] Loss: 0.6642
# [Epoch 45/250] Loss: 0.6625
# [Epoch 46/250] Loss: 0.6631
# [Epoch 47/250] Loss: 0.6625
# [Epoch 48/250] Loss: 0.6625
# [Epoch 49/250] Loss: 0.6621
# [Epoch 50/250] Loss: 0.6610
# [Epoch 51/250] Loss: 0.6606
# [Epoch 52/250] Loss: 0.6589
# [Epoch 53/250] Loss: 0.6581
# [Epoch 54/250] Loss: 0.6587
# [Epoch 55/250] Loss: 0.6581
# [Epoch 56/250] Loss: 0.6594
# [Epoch 57/250] Loss: 0.6569
# [Epoch 58/250] Loss: 0.6566
# [Epoch 59/250] Loss: 0.6564
# [Epoch 60/250] Loss: 0.6553
# [Epoch 61/250] Loss: 0.6544
# [Epoch 62/250] Loss: 0.6533
# [Epoch 63/250] Loss: 0.6547
# [Epoch 64/250] Loss: 0.6545
# [Epoch 65/250] Loss: 0.6523
# [Epoch 66/250] Loss: 0.6537
# [Epoch 67/250] Loss: 0.6527
# [Epoch 68/250] Loss: 0.6510
# [Epoch 69/250] Loss: 0.6523
# [Epoch 70/250] Loss: 0.6515
# [Epoch 71/250] Loss: 0.6527
# [Epoch 72/250] Loss: 0.6517
# [Epoch 73/250] Loss: 0.6461
# [Epoch 74/250] Loss: 0.6449
# [Epoch 75/250] Loss: 0.6429
# [Epoch 76/250] Loss: 0.6439
# [Epoch 77/250] Loss: 0.6419
# [Epoch 78/250] Loss: 0.6431
# [Epoch 79/250] Loss: 0.6414
# [Epoch 80/250] Loss: 0.6419
# [Epoch 81/250] Loss: 0.6418
# [Epoch 82/250] Loss: 0.6409
# [Epoch 83/250] Loss: 0.6410
# [Epoch 84/250] Loss: 0.6400
# [Epoch 85/250] Loss: 0.6406
# [Epoch 86/250] Loss: 0.6387
# [Epoch 87/250] Loss: 0.6394
# [Epoch 88/250] Loss: 0.6408
# [Epoch 89/250] Loss: 0.6402
# [Epoch 90/250] Loss: 0.6396
# [Epoch 91/250] Loss: 0.6391
# [Epoch 92/250] Loss: 0.6391
# [Epoch 93/250] Loss: 0.6402
# [Epoch 94/250] Loss: 0.6392
# [Epoch 95/250] Loss: 0.6393
# [Epoch 96/250] Loss: 0.6392
# [Epoch 97/250] Loss: 0.6394
# [Epoch 98/250] Loss: 0.6382
# [Epoch 99/250] Loss: 0.6385
# [Epoch 100/250] Loss: 0.6382
# [Epoch 101/250] Loss: 0.6392
# [Epoch 102/250] Loss: 0.6382
# [Epoch 103/250] Loss: 0.6390
# [Epoch 104/250] Loss: 0.6375
# [Epoch 105/250] Loss: 0.6398
# [Epoch 106/250] Loss: 0.6403
# [Epoch 107/250] Loss: 0.6381
# [Epoch 108/250] Loss: 0.6387
# [Epoch 109/250] Loss: 0.6389
# [Epoch 110/250] Loss: 0.6390
# [Epoch 111/250] Loss: 0.6395
# [Epoch 112/250] Loss: 0.6387
# [Epoch 113/250] Loss: 0.6394
# [Epoch 114/250] Loss: 0.6390
# [Epoch 115/250] Loss: 0.6400
# [Epoch 116/250] Loss: 0.6394
# [Epoch 117/250] Loss: 0.6380
# [Epoch 118/250] Loss: 0.6388
# [Epoch 119/250] Loss: 0.6386
# [Epoch 120/250] Loss: 0.6402
# [Epoch 121/250] Loss: 0.6397
# [Epoch 122/250] Loss: 0.6385
# [Epoch 123/250] Loss: 0.6392
# [Epoch 124/250] Loss: 0.6396
# [Epoch 125/250] Loss: 0.6397
# [Epoch 126/250] Loss: 0.6398
# [Epoch 127/250] Loss: 0.6399
# [Epoch 128/250] Loss: 0.6395
# [Epoch 129/250] Loss: 0.6386
# Early stopping triggered at epoch 129
# [Classifier Epoch 1/250] Loss: 8.4542
# [Classifier Epoch 2/250] Loss: 7.8063
# [Classifier Epoch 3/250] Loss: 6.5272
# [Classifier Epoch 4/250] Loss: 4.9949
# [Classifier Epoch 5/250] Loss: 3.4838
# [Classifier Epoch 6/250] Loss: 2.4509
# [Classifier Epoch 7/250] Loss: 1.9510
# [Classifier Epoch 8/250] Loss: 1.6482
# [Classifier Epoch 9/250] Loss: 1.5021
# [Classifier Epoch 10/250] Loss: 1.3573
# [Classifier Epoch 11/250] Loss: 1.2530
# [Classifier Epoch 12/250] Loss: 1.1834
# [Classifier Epoch 13/250] Loss: 1.0931
# [Classifier Epoch 14/250] Loss: 1.0294
# [Classifier Epoch 15/250] Loss: 0.9887
# [Classifier Epoch 16/250] Loss: 0.9419
# [Classifier Epoch 17/250] Loss: 0.9713
# [Classifier Epoch 18/250] Loss: 0.9276
# [Classifier Epoch 19/250] Loss: 0.8518
# [Classifier Epoch 20/250] Loss: 0.8349
# [Classifier Epoch 21/250] Loss: 0.8051
# [Classifier Epoch 22/250] Loss: 0.8176
# [Classifier Epoch 23/250] Loss: 0.7885
# [Classifier Epoch 24/250] Loss: 0.7953
# [Classifier Epoch 25/250] Loss: 0.7607
# [Classifier Epoch 26/250] Loss: 0.7287
# [Classifier Epoch 27/250] Loss: 0.7083
# [Classifier Epoch 28/250] Loss: 0.7071
# [Classifier Epoch 29/250] Loss: 0.7351
# [Classifier Epoch 30/250] Loss: 0.6781
# [Classifier Epoch 31/250] Loss: 0.6575
# [Classifier Epoch 32/250] Loss: 0.6704
# [Classifier Epoch 33/250] Loss: 0.6340
# [Classifier Epoch 34/250] Loss: 0.6494
# [Classifier Epoch 35/250] Loss: 0.6506
# [Classifier Epoch 36/250] Loss: 0.6263
# [Classifier Epoch 37/250] Loss: 0.6614
# [Classifier Epoch 38/250] Loss: 0.6315
# [Classifier Epoch 39/250] Loss: 0.6291
# [Classifier Epoch 40/250] Loss: 0.6105
# [Classifier Epoch 41/250] Loss: 0.5986
# [Classifier Epoch 42/250] Loss: 0.6015
# [Classifier Epoch 43/250] Loss: 0.5878
# [Classifier Epoch 44/250] Loss: 0.5842
# [Classifier Epoch 45/250] Loss: 0.6117
# [Classifier Epoch 46/250] Loss: 0.5607
# [Classifier Epoch 47/250] Loss: 0.5999
# [Classifier Epoch 48/250] Loss: 0.5802
# [Classifier Epoch 49/250] Loss: 0.5252
# [Classifier Epoch 50/250] Loss: 0.5531
# [Classifier Epoch 51/250] Loss: 0.5549
# [Classifier Epoch 52/250] Loss: 0.5332
# [Classifier Epoch 53/250] Loss: 0.5364
# [Classifier Epoch 54/250] Loss: 0.5001
# [Classifier Epoch 55/250] Loss: 0.5769
# [Classifier Epoch 56/250] Loss: 0.5693
# [Classifier Epoch 57/250] Loss: 0.5139
# [Classifier Epoch 58/250] Loss: 0.5214
# [Classifier Epoch 59/250] Loss: 0.5232
# Early stopping triggered at epoch 59
# Building Recs: 100%|███████████████████████████████████████████████████████████████| 5148/5148 [01:36<00:00, 53.16it/s]

# %%
import os
import pandas as pd
import numpy as np

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from tqdm import tqdm
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import warnings

warnings.filterwarnings("ignore")

def cosine_similarity(vec_a, vec_b, eps=1e-9):
    dot = np.dot(vec_a, vec_b)
    norm_a = np.linalg.norm(vec_a)
    norm_b = np.linalg.norm(vec_b)
    return dot / ((norm_a * norm_b) + eps)

def load_and_merge_numeric_features(file_list, merge_on='id'):
    base_df = pd.read_csv(file_list[0], sep='\t')
    for path in file_list[1:]:
        df_next = pd.read_csv(path, sep='\t')
        base_df = pd.merge(base_df, df_next, on=merge_on, how='inner')
    base_df.set_index(merge_on, inplace=True)
    return base_df

def normalize_features(df):
    scaler = StandardScaler()
    return pd.DataFrame(scaler.fit_transform(df), index=df.index, columns=df.columns)

class Music4AllOnionDataset(Dataset):
    def __init__(self, feature_df, label_df=None, transform=None):
        self.transform = transform
        feature_df = feature_df.sort_index()
        self.feature_df = feature_df

        if label_df is not None:
            label_df = label_df.sort_index()
            common_idx = feature_df.index.intersection(label_df.index)
            self.feature_df = feature_df.loc[common_idx]
            self.label_df = label_df.loc[common_idx]
            self.has_labels = True
        else:
            self.label_df = None
            self.has_labels = False

        self.feature_data = self.feature_df.values.astype(np.float32)
        if self.transform:
            self.feature_data = self.transform(self.feature_data)

    def __len__(self):
        return len(self.feature_data)

    def __getitem__(self, idx):
        x = self.feature_data[idx]
        x = torch.tensor(x, dtype=torch.float32)

        if self.has_labels:
            y_val = self.label_df.iloc[idx].values
            y_val = torch.tensor(y_val, dtype=torch.long)
            return x, y_val
        else:
            return x

class MKGCN(nn.Module):
    def __init__(self, input_dim, latent_dim=128):
        super(MKGCN, self).__init__()
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, 512),
            nn.BatchNorm1d(512),
            nn.LeakyReLU(),
            nn.Dropout(0.3),
            nn.Linear(512, 256),
            nn.BatchNorm1d(256),
            nn.LeakyReLU(),
            nn.Dropout(0.3),
            nn.Linear(256, latent_dim)
        )
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, 256),
            nn.BatchNorm1d(256),
            nn.LeakyReLU(),
            nn.Dropout(0.3),
            nn.Linear(256, 512),
            nn.BatchNorm1d(512),
            nn.LeakyReLU(),
            nn.Dropout(0.3),
            nn.Linear(512, input_dim)
        )

    def forward(self, x, reconstruct=False):
        z = self.encoder(x)
        if reconstruct:
            return self.decoder(z)
        return z

class FineTuneClassifier(nn.Module):
    def __init__(self, mkgcn, latent_dim, num_classes):
        super(FineTuneClassifier, self).__init__()
        self.mkgcn = mkgcn
        for param in self.mkgcn.encoder.parameters():
            param.requires_grad = False  

        self.classifier = nn.Sequential(
            nn.Linear(latent_dim, 64),
            nn.LeakyReLU(),
            nn.Linear(64, num_classes)
        )

    def forward(self, x):
        with torch.no_grad():
            z = self.mkgcn.encoder(x)  
        logits = self.classifier(z)
        return logits

def train_mkgcn(model, dataloader, num_epochs=50, lr=1e-3, patience=5, device='cuda'):
    model.to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr)
    criterion = nn.MSELoss()
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=3)

    best_loss = float('inf')
    patience_counter = 0
    best_model_state = None

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for x, _ in dataloader:
            x = x.to(device)
            optimizer.zero_grad()
            x_recon = model(x, reconstruct=True)
            loss = criterion(x_recon, x)  
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        avg_loss = running_loss / len(dataloader)
        print(f"[Epoch {epoch+1}/{num_epochs}] Loss: {avg_loss:.4f}")

        scheduler.step(avg_loss)

        if avg_loss < best_loss:
            best_loss = avg_loss
            patience_counter = 0
            best_model_state = model.state_dict()
        else:
            patience_counter += 1

        if patience_counter >= patience:
            print(f"Early stopping triggered at epoch {epoch+1}")
            break

    if best_model_state is not None:
        model.load_state_dict(best_model_state)


def train_classifier(
    model, dataloader, num_epochs=20, lr=1e-3, patience=5, device='cuda'
):
    model.to(device)
    optimizer = optim.Adam(model.classifier.parameters(), lr=lr)
    criterion = nn.CrossEntropyLoss()
    best_loss = float("inf")
    patience_counter = 0
    best_model_state = None

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for x, y in dataloader:
            x, y = x.to(device), y.to(device)
            optimizer.zero_grad()
            logits = model(x)
            loss = criterion(logits, y.squeeze().long())
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

        avg_loss = running_loss / len(dataloader)
        print(f"[Classifier Epoch {epoch+1}/{num_epochs}] Loss: {avg_loss:.4f}")

        if avg_loss < best_loss:
            best_loss = avg_loss
            patience_counter = 0
            best_model_state = model.state_dict()
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print(f"Early stopping triggered at epoch {epoch+1}")
                break

    if best_model_state is not None:
        model.load_state_dict(best_model_state)

def compute_all_embeddings(dataset, model, device='cuda'):
    model.eval()
    all_embeddings = []

    for i in range(len(dataset)):
        item = dataset[i]
        x = item[0] if isinstance(item, tuple) else item
        x = x.unsqueeze(0).to(device)
        with torch.no_grad():
            z = model(x)
        z_np = z.cpu().numpy().flatten()
        all_embeddings.append(z_np)

    embeddings = np.vstack(all_embeddings)
    return embeddings

def build_recommendations(embeddings, ids, infos, topK=10):
    recommendations = []
    N = len(embeddings)

    for i in tqdm(range(N), desc="Building Recommendations"):
        vec_i = embeddings[i]
        sims = [
            {"source_id": ids[i], "target_id": ids[j], "similarity": cosine_similarity(vec_i, embeddings[j])}
            for j in range(N) if i != j
        ]
        top_k_recs = sorted(sims, key=lambda x: x["similarity"], reverse=True)[:topK]
        recommendations.extend(top_k_recs)

    return pd.DataFrame(recommendations)

device = "cuda" if torch.cuda.is_available() else "cpu"

numeric_files = [
        "id_blf_correlation_mmsr.tsv",
        "id_blf_deltaspectral_mmsr.tsv",
        "id_blf_logfluc_mmsr.tsv",
        "id_blf_spectral_mmsr.tsv",
        "id_blf_spectralcontrast_mmsr.tsv",
        "id_blf_vardeltaspectral_mmsr.tsv",
        "id_incp_mmsr.tsv",
        "id_ivec256_mmsr.tsv",
        "id_ivec512_mmsr.tsv",
        "id_ivec1024_mmsr.tsv",
        "id_lyrics_tf-idf_mmsr.tsv",
        "id_lyrics_word2vec_mmsr.tsv",
        "id_lyrics_bert_mmsr.tsv",
        "id_mfcc_bow_mmsr.tsv",
        "id_mfcc_stats_mmsr.tsv",
        "id_musicnn_mmsr.tsv",
        "id_resnet_mmsr.tsv",
        "id_vgg19_mmsr.tsv",
        "id_total_listens.tsv"
]

fused_df = load_and_merge_numeric_features(numeric_files, merge_on='id')
fused_df_normalized = normalize_features(fused_df)

labels_path = "id_genres_mmsr.tsv"
if os.path.exists(labels_path):
    labels_df = pd.read_csv(labels_path, sep='\t').set_index('id')
    unique_genres = labels_df['genre'].unique()
    genre_to_idx = {g: i for i, g in enumerate(unique_genres)}
    labels_df['genre_id'] = labels_df['genre'].map(genre_to_idx)
    final_labels_df = labels_df[['genre_id']]
else:
    final_labels_df = None

feature_train, feature_test, label_train, label_test = train_test_split(
        fused_df_normalized, final_labels_df, test_size=0.2, random_state=42
)

train_dataset = Music4AllOnionDataset(feature_train, label_train)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
    
test_dataset = Music4AllOnionDataset(feature_test, label_test)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

input_dim = fused_df_normalized.shape[1]
latent_dim = 128

mkgcn_model = MKGCN(input_dim, latent_dim=latent_dim)
train_mkgcn(mkgcn_model, train_loader, num_epochs=250, lr=1e-3, patience=150, device=device)

if final_labels_df is not None:
    num_classes = len(np.unique(final_labels_df['genre_id']))
    classifier_model = FineTuneClassifier(mkgcn_model, latent_dim, num_classes)
    train_classifier(classifier_model, train_loader, num_epochs=250, patience=100, lr=1e-3, device=device)

full_dataset = Music4AllOnionDataset(fused_df_normalized)
embeddings = compute_all_embeddings(full_dataset, mkgcn_model, device=device)
ids = fused_df_normalized.index.tolist()

recommendations = build_recommendations(embeddings, ids, fused_df_normalized, topK=100)
recommendations.to_csv("recs_mkgcn_10.csv", index=False)
# Out:
# [Epoch 1/250] Loss: 0.8729
# [Epoch 2/250] Loss: 0.7942
# [Epoch 3/250] Loss: 0.7673
# [Epoch 4/250] Loss: 0.7556
# [Epoch 5/250] Loss: 0.7417
# [Epoch 6/250] Loss: 0.7348
# [Epoch 7/250] Loss: 0.7281
# [Epoch 8/250] Loss: 0.7234
# [Epoch 9/250] Loss: 0.7183
# [Epoch 10/250] Loss: 0.7185
# [Epoch 11/250] Loss: 0.7109
# [Epoch 12/250] Loss: 0.7100
# [Epoch 13/250] Loss: 0.7071
# [Epoch 14/250] Loss: 0.7033
# [Epoch 15/250] Loss: 0.7026
# [Epoch 16/250] Loss: 0.6979
# [Epoch 17/250] Loss: 0.6946
# [Epoch 18/250] Loss: 0.6922
# [Epoch 19/250] Loss: 0.6935
# [Epoch 20/250] Loss: 0.6905
# [Epoch 21/250] Loss: 0.6886
# [Epoch 22/250] Loss: 0.6882
# [Epoch 23/250] Loss: 0.6861
# [Epoch 24/250] Loss: 0.6823
# [Epoch 25/250] Loss: 0.6807
# [Epoch 26/250] Loss: 0.6798
# [Epoch 27/250] Loss: 0.6782
# [Epoch 28/250] Loss: 0.6760
# [Epoch 29/250] Loss: 0.6751
# [Epoch 30/250] Loss: 0.6747
# [Epoch 31/250] Loss: 0.6734
# [Epoch 32/250] Loss: 0.6743
# [Epoch 33/250] Loss: 0.6716
# [Epoch 34/250] Loss: 0.6712
# [Epoch 35/250] Loss: 0.6704
# [Epoch 36/250] Loss: 0.6707
# [Epoch 37/250] Loss: 0.6690
# [Epoch 38/250] Loss: 0.6681
# [Epoch 39/250] Loss: 0.6679
# [Epoch 40/250] Loss: 0.6683
# [Epoch 41/250] Loss: 0.6660
# [Epoch 42/250] Loss: 0.6657
# [Epoch 43/250] Loss: 0.6630
# [Epoch 44/250] Loss: 0.6653
# [Epoch 45/250] Loss: 0.6653
# [Epoch 46/250] Loss: 0.6607
# [Epoch 47/250] Loss: 0.6613
# [Epoch 48/250] Loss: 0.6605
# [Epoch 49/250] Loss: 0.6594
# [Epoch 50/250] Loss: 0.6593
# [Epoch 51/250] Loss: 0.6590
# [Epoch 52/250] Loss: 0.6577
# [Epoch 53/250] Loss: 0.6568
# [Epoch 54/250] Loss: 0.6564
# [Epoch 55/250] Loss: 0.6564
# [Epoch 56/250] Loss: 0.6539
# [Epoch 57/250] Loss: 0.6553
# [Epoch 58/250] Loss: 0.6541
# [Epoch 59/250] Loss: 0.6538
# [Epoch 60/250] Loss: 0.6532
# [Epoch 61/250] Loss: 0.6524
# [Epoch 62/250] Loss: 0.6514
# [Epoch 63/250] Loss: 0.6523
# [Epoch 64/250] Loss: 0.6534
# [Epoch 65/250] Loss: 0.6516
# [Epoch 66/250] Loss: 0.6504
# [Epoch 67/250] Loss: 0.6474
# [Epoch 68/250] Loss: 0.6497
# [Epoch 69/250] Loss: 0.6489
# [Epoch 70/250] Loss: 0.6488
# [Epoch 71/250] Loss: 0.6488
# [Epoch 72/250] Loss: 0.6438
# [Epoch 73/250] Loss: 0.6411
# [Epoch 74/250] Loss: 0.6416
# [Epoch 75/250] Loss: 0.6402
# [Epoch 76/250] Loss: 0.6397
# [Epoch 77/250] Loss: 0.6393
# [Epoch 78/250] Loss: 0.6386
# [Epoch 79/250] Loss: 0.6399
# [Epoch 80/250] Loss: 0.6405
# [Epoch 81/250] Loss: 0.6389
# [Epoch 82/250] Loss: 0.6386
# [Epoch 83/250] Loss: 0.6398
# [Epoch 84/250] Loss: 0.6378
# [Epoch 85/250] Loss: 0.6382
# [Epoch 86/250] Loss: 0.6375
# [Epoch 87/250] Loss: 0.6379
# [Epoch 88/250] Loss: 0.6374
# [Epoch 89/250] Loss: 0.6363
# [Epoch 90/250] Loss: 0.6375
# [Epoch 91/250] Loss: 0.6386
# [Epoch 92/250] Loss: 0.6373
# [Epoch 93/250] Loss: 0.6372
# [Epoch 94/250] Loss: 0.6374
# [Epoch 95/250] Loss: 0.6386
# [Epoch 96/250] Loss: 0.6374
# [Epoch 97/250] Loss: 0.6385
# [Epoch 98/250] Loss: 0.6381
# [Epoch 99/250] Loss: 0.6371
# [Epoch 100/250] Loss: 0.6380
# [Epoch 101/250] Loss: 0.6366
# [Epoch 102/250] Loss: 0.6376
# [Epoch 103/250] Loss: 0.6376
# [Epoch 104/250] Loss: 0.6377
# [Epoch 105/250] Loss: 0.6382
# [Epoch 106/250] Loss: 0.6382
# [Epoch 107/250] Loss: 0.6365
# [Epoch 108/250] Loss: 0.6369
# [Epoch 109/250] Loss: 0.6378
# [Epoch 110/250] Loss: 0.6374
# [Epoch 111/250] Loss: 0.6372
# [Epoch 112/250] Loss: 0.6373
# [Epoch 113/250] Loss: 0.6387
# [Epoch 114/250] Loss: 0.6369
# Early stopping triggered at epoch 114
# [Classifier Epoch 1/250] Loss: 8.4332
# [Classifier Epoch 2/250] Loss: 7.7926
# [Classifier Epoch 3/250] Loss: 6.5113
# [Classifier Epoch 4/250] Loss: 4.9325
# [Classifier Epoch 5/250] Loss: 3.4459
# [Classifier Epoch 6/250] Loss: 2.4426
# [Classifier Epoch 7/250] Loss: 1.8750
# [Classifier Epoch 8/250] Loss: 1.5645
# [Classifier Epoch 9/250] Loss: 1.4046
# [Classifier Epoch 10/250] Loss: 1.2542
# [Classifier Epoch 11/250] Loss: 1.1762
# [Classifier Epoch 12/250] Loss: 1.1061
# [Classifier Epoch 13/250] Loss: 1.0704
# [Classifier Epoch 14/250] Loss: 0.9646
# [Classifier Epoch 15/250] Loss: 0.9461
# [Classifier Epoch 16/250] Loss: 0.8839
# [Classifier Epoch 17/250] Loss: 0.8892
# [Classifier Epoch 18/250] Loss: 0.8446
# [Classifier Epoch 19/250] Loss: 0.8383
# [Classifier Epoch 20/250] Loss: 0.7760
# [Classifier Epoch 21/250] Loss: 0.7862
# [Classifier Epoch 22/250] Loss: 0.7350
# [Classifier Epoch 23/250] Loss: 0.6956
# [Classifier Epoch 24/250] Loss: 0.7167
# [Classifier Epoch 25/250] Loss: 0.6610
# [Classifier Epoch 26/250] Loss: 0.6677
# [Classifier Epoch 27/250] Loss: 0.6955
# [Classifier Epoch 28/250] Loss: 0.6494
# [Classifier Epoch 29/250] Loss: 0.6553
# [Classifier Epoch 30/250] Loss: 0.6707
# [Classifier Epoch 31/250] Loss: 0.6174
# [Classifier Epoch 32/250] Loss: 0.6273
# [Classifier Epoch 33/250] Loss: 0.5889
# [Classifier Epoch 34/250] Loss: 0.6304
# [Classifier Epoch 35/250] Loss: 0.6136
# [Classifier Epoch 36/250] Loss: 0.5592
# [Classifier Epoch 37/250] Loss: 0.5675
# [Classifier Epoch 38/250] Loss: 0.6022
# [Classifier Epoch 39/250] Loss: 0.5639
# [Classifier Epoch 40/250] Loss: 0.5603
# [Classifier Epoch 41/250] Loss: 0.5654
# Early stopping triggered at epoch 41
# Building Recommendations: 100%|████████████████████████████████████████████████████| 5148/5148 [01:50<00:00, 46.57it/s]
