# %%
import os
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from tqdm import tqdm
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import warnings

warnings.filterwarnings("ignore")


def cosine_similarity(vec_a, vec_b, eps=1e-9):
    dot = np.dot(vec_a, vec_b)
    norm_a = np.linalg.norm(vec_a)
    norm_b = np.linalg.norm(vec_b)
    return dot / ((norm_a * norm_b) + eps)


def load_and_merge_numeric_features(file_list, merge_on='id'):
    base_df = pd.read_csv(file_list[0], sep='\t')
    for path in file_list[1:]:
        df_next = pd.read_csv(path, sep='\t')
        base_df = pd.merge(base_df, df_next, on=merge_on, how='inner')
    base_df.set_index(merge_on, inplace=True)
    return base_df

def normalize_features(df):
    scaler = StandardScaler()
    return pd.DataFrame(scaler.fit_transform(df), index=df.index, columns=df.columns)

class Music4AllOnionDataset(Dataset):
    def __init__(self, feature_df, label_df=None, transform=None):
        self.transform = transform
        feature_df = feature_df.sort_index()
        self.feature_df = feature_df

        if label_df is not None:
            label_df = label_df.sort_index()
            common_idx = feature_df.index.intersection(label_df.index)
            self.feature_df = feature_df.loc[common_idx]
            self.label_df = label_df.loc[common_idx]
            self.has_labels = True
        else:
            self.label_df = None
            self.has_labels = False

        self.feature_data = self.feature_df.values.astype(np.float32)
        if self.transform:
            self.feature_data = self.transform(self.feature_data)

    def __len__(self):
        return len(self.feature_data)

    def __getitem__(self, idx):
        x = self.feature_data[idx]
        x = torch.tensor(x, dtype=torch.float32)

        if self.has_labels:
            y_val = self.label_df.iloc[idx].values
            y_val = torch.tensor(y_val, dtype=torch.long)
            return x, y_val
        else:
            return x

class MKGCN(nn.Module):
    def __init__(self, input_dim, latent_dim=128):
        super(MKGCN, self).__init__()
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, 512),
            nn.BatchNorm1d(512),
            nn.LeakyReLU(),
            nn.Dropout(0.3),
            nn.Linear(512, 256),
            nn.BatchNorm1d(256),
            nn.LeakyReLU(),
            nn.Dropout(0.3),
            nn.Linear(256, latent_dim)
        )
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, 256),
            nn.BatchNorm1d(256),
            nn.LeakyReLU(),
            nn.Dropout(0.3),
            nn.Linear(256, 512),
            nn.BatchNorm1d(512),
            nn.LeakyReLU(),
            nn.Dropout(0.3),
            nn.Linear(512, input_dim)
        )

    def forward(self, x, reconstruct=False):
        z = self.encoder(x)
        if reconstruct:
            return self.decoder(z)
        return z

class FineTuneClassifier(nn.Module):
    def __init__(self, mkgcn, latent_dim, num_classes):
        super(FineTuneClassifier, self).__init__()
        self.mkgcn = mkgcn
        for param in self.mkgcn.encoder.parameters():
            param.requires_grad = False  

        self.classifier = nn.Sequential(
            nn.Linear(latent_dim, 64),
            nn.LeakyReLU(),
            nn.Linear(64, num_classes)
        )

    def forward(self, x):
        with torch.no_grad():
            z = self.mkgcn.encoder(x)  
        logits = self.classifier(z)
        return logits

def train_mkgcn(model, dataloader, num_epochs=50, lr=1e-3, patience=5, device='cuda'):
    model.to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr)
    criterion = nn.MSELoss()
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=3)

    best_loss = float('inf')
    patience_counter = 0
    best_model_state = None

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for x, _ in dataloader:
            x = x.to(device)
            optimizer.zero_grad()
            x_recon = model(x, reconstruct=True)
            loss = criterion(x_recon, x)  
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        avg_loss = running_loss / len(dataloader)
        print(f"[Epoch {epoch+1}/{num_epochs}] Loss: {avg_loss:.4f}")

        scheduler.step(avg_loss)

        if avg_loss < best_loss:
            best_loss = avg_loss
            patience_counter = 0
            best_model_state = model.state_dict()
        else:
            patience_counter += 1

        if patience_counter >= patience:
            print(f"Early stopping triggered at epoch {epoch+1}")
            break

    if best_model_state is not None:
        model.load_state_dict(best_model_state)


def train_classifier(
    model, dataloader, num_epochs=20, lr=1e-3, patience=5, device='cuda'
):
    model.to(device)
    optimizer = optim.Adam(model.classifier.parameters(), lr=lr)
    criterion = nn.CrossEntropyLoss()
    best_loss = float("inf")
    patience_counter = 0
    best_model_state = None

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for x, y in dataloader:
            x, y = x.to(device), y.to(device)
            optimizer.zero_grad()
            logits = model(x)
            loss = criterion(logits, y.squeeze().long())
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

        avg_loss = running_loss / len(dataloader)
        print(f"[Classifier Epoch {epoch+1}/{num_epochs}] Loss: {avg_loss:.4f}")

        if avg_loss < best_loss:
            best_loss = avg_loss
            patience_counter = 0
            best_model_state = model.state_dict()
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print(f"Early stopping triggered at epoch {epoch+1}")
                break

    if best_model_state is not None:
        model.load_state_dict(best_model_state)

def compute_all_embeddings(dataset, model, device='cuda'):
    model.eval()
    all_embeddings = []

    for i in range(len(dataset)):
        item = dataset[i]
        x = item[0] if isinstance(item, tuple) else item
        x = x.unsqueeze(0).to(device)
        with torch.no_grad():
            z = model(x)
        z_np = z.cpu().numpy().flatten()
        all_embeddings.append(z_np)

    embeddings = np.vstack(all_embeddings)
    return embeddings

def build_recommendation_matrix(embeddings, topK=10):
    N = len(embeddings)
    rec_matrix = np.zeros((N, N), dtype=np.float32)

    for i in tqdm(range(N), desc="Building Recs"):
        vec_i = embeddings[i]
        sims = [cosine_similarity(vec_i, embeddings[j]) for j in range(N)]
        sims = np.array(sims)
        sims[i] = -1e9
        topk_idx = sims.argsort()[::-1][:topK]
        topk_vals = sims[topk_idx]
        rec_matrix[i, topk_idx] = topk_vals

    return rec_matrix

device = "cuda" if torch.cuda.is_available() else "cpu"

numeric_files = [
        "id_blf_correlation_mmsr.tsv",
        "id_blf_deltaspectral_mmsr.tsv",
        "id_blf_logfluc_mmsr.tsv",
        "id_blf_spectral_mmsr.tsv",
        "id_blf_spectralcontrast_mmsr.tsv",
        "id_blf_vardeltaspectral_mmsr.tsv",
        "id_incp_mmsr.tsv",
        "id_ivec256_mmsr.tsv",
        "id_ivec512_mmsr.tsv",
        "id_ivec1024_mmsr.tsv",
        "id_lyrics_tf-idf_mmsr.tsv",
        "id_lyrics_word2vec_mmsr.tsv",
        "id_lyrics_bert_mmsr.tsv",
        "id_mfcc_bow_mmsr.tsv",
        "id_mfcc_stats_mmsr.tsv",
        "id_musicnn_mmsr.tsv",
        "id_resnet_mmsr.tsv",
        "id_vgg19_mmsr.tsv",
        "id_total_listens.tsv"
]

fused_df = load_and_merge_numeric_features(numeric_files, merge_on='id')
fused_df_normalized = normalize_features(fused_df)

labels_path = "id_genres_mmsr.tsv"
if os.path.exists(labels_path):
        labels_df = pd.read_csv(labels_path, sep='\t').set_index('id')
        unique_genres = labels_df['genre'].unique()
        genre_to_idx = {g: i for i, g in enumerate(unique_genres)}
        labels_df['genre_id'] = labels_df['genre'].map(genre_to_idx)
        final_labels_df = labels_df[['genre_id']]
else:
    final_labels_df = None

feature_train, feature_test, label_train, label_test = train_test_split(
        fused_df_normalized, final_labels_df, test_size=0.2, random_state=42
)

train_dataset = Music4AllOnionDataset(feature_train, label_train)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
    
test_dataset = Music4AllOnionDataset(feature_test, label_test)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

input_dim = fused_df_normalized.shape[1]
latent_dim = 128

mkgcn_model = MKGCN(input_dim, latent_dim=latent_dim)
train_mkgcn(mkgcn_model, train_loader, num_epochs=250, lr=1e-3, patience=100, device=device)

if final_labels_df is not None:
    num_classes = len(np.unique(final_labels_df['genre_id']))
    classifier_model = FineTuneClassifier(mkgcn_model, latent_dim, num_classes)
    train_classifier(classifier_model, train_loader, num_epochs=250, patience=100, lr=1e-3, device=device)

full_dataset = Music4AllOnionDataset(fused_df_normalized)
embeddings = compute_all_embeddings(full_dataset, mkgcn_model, device=device)
rec_matrix = build_recommendation_matrix(embeddings, topK=10)
np.savetxt("recs_mkgcn_1_10.csv", rec_matrix, delimiter="\t")
# Out:
# [Epoch 1/250] Loss: 0.8635
# [Epoch 2/250] Loss: 0.7821
# [Epoch 3/250] Loss: 0.7604
# [Epoch 4/250] Loss: 0.7498
# [Epoch 5/250] Loss: 0.7417
# [Epoch 6/250] Loss: 0.7328
# [Epoch 7/250] Loss: 0.7301
# [Epoch 8/250] Loss: 0.7232
# [Epoch 9/250] Loss: 0.7224
# [Epoch 10/250] Loss: 0.7160
# [Epoch 11/250] Loss: 0.7141
# [Epoch 12/250] Loss: 0.7107
# [Epoch 13/250] Loss: 0.7065
# [Epoch 14/250] Loss: 0.7034
# [Epoch 15/250] Loss: 0.7018
# [Epoch 16/250] Loss: 0.7006
# [Epoch 17/250] Loss: 0.6972
# [Epoch 18/250] Loss: 0.6946
# [Epoch 19/250] Loss: 0.6930
# [Epoch 20/250] Loss: 0.6920
# [Epoch 21/250] Loss: 0.6902
# [Epoch 22/250] Loss: 0.6892
# [Epoch 23/250] Loss: 0.6874
# [Epoch 24/250] Loss: 0.6862
# [Epoch 25/250] Loss: 0.6831
# [Epoch 26/250] Loss: 0.6837
# [Epoch 27/250] Loss: 0.6818
# [Epoch 28/250] Loss: 0.6820
# [Epoch 29/250] Loss: 0.6788
# [Epoch 30/250] Loss: 0.6780
# [Epoch 31/250] Loss: 0.6751
# [Epoch 32/250] Loss: 0.6723
# [Epoch 33/250] Loss: 0.6733
# [Epoch 34/250] Loss: 0.6720
# [Epoch 35/250] Loss: 0.6718
# [Epoch 36/250] Loss: 0.6692
# [Epoch 37/250] Loss: 0.6697
# [Epoch 38/250] Loss: 0.6704
# [Epoch 39/250] Loss: 0.6683
# [Epoch 40/250] Loss: 0.6664
# [Epoch 41/250] Loss: 0.6653
# [Epoch 42/250] Loss: 0.6647
# [Epoch 43/250] Loss: 0.6653
# [Epoch 44/250] Loss: 0.6653
# [Epoch 45/250] Loss: 0.6621
# [Epoch 46/250] Loss: 0.6613
# [Epoch 47/250] Loss: 0.6601
# [Epoch 48/250] Loss: 0.6603
# [Epoch 49/250] Loss: 0.6604
# [Epoch 50/250] Loss: 0.6591
# [Epoch 51/250] Loss: 0.6576
# [Epoch 52/250] Loss: 0.6589
# [Epoch 53/250] Loss: 0.6565
# [Epoch 54/250] Loss: 0.6572
# [Epoch 55/250] Loss: 0.6562
# [Epoch 56/250] Loss: 0.6551
# [Epoch 57/250] Loss: 0.6556
# [Epoch 58/250] Loss: 0.6537
# [Epoch 59/250] Loss: 0.6536
# [Epoch 60/250] Loss: 0.6546
# [Epoch 61/250] Loss: 0.6550
# [Epoch 62/250] Loss: 0.6528
# [Epoch 63/250] Loss: 0.6530
# [Epoch 64/250] Loss: 0.6521
# [Epoch 65/250] Loss: 0.6514
# [Epoch 66/250] Loss: 0.6511
# [Epoch 67/250] Loss: 0.6500
# [Epoch 68/250] Loss: 0.6493
# [Epoch 69/250] Loss: 0.6487
# [Epoch 70/250] Loss: 0.6501
# [Epoch 71/250] Loss: 0.6499
# [Epoch 72/250] Loss: 0.6480
# [Epoch 73/250] Loss: 0.6485
# [Epoch 74/250] Loss: 0.6483
# [Epoch 75/250] Loss: 0.6477
# [Epoch 76/250] Loss: 0.6467
# [Epoch 77/250] Loss: 0.6461
# [Epoch 78/250] Loss: 0.6464
# [Epoch 79/250] Loss: 0.6457
# [Epoch 80/250] Loss: 0.6462
# [Epoch 81/250] Loss: 0.6465
# [Epoch 82/250] Loss: 0.6455
# [Epoch 83/250] Loss: 0.6437
# [Epoch 84/250] Loss: 0.6443
# [Epoch 85/250] Loss: 0.6436
# [Epoch 86/250] Loss: 0.6444
# [Epoch 87/250] Loss: 0.6440
# [Epoch 88/250] Loss: 0.6394
# [Epoch 89/250] Loss: 0.6379
# [Epoch 90/250] Loss: 0.6372
# [Epoch 91/250] Loss: 0.6369
# [Epoch 92/250] Loss: 0.6345
# [Epoch 93/250] Loss: 0.6360
# [Epoch 94/250] Loss: 0.6345
# [Epoch 95/250] Loss: 0.6344
# [Epoch 96/250] Loss: 0.6346
# [Epoch 97/250] Loss: 0.6339
# [Epoch 98/250] Loss: 0.6351
# [Epoch 99/250] Loss: 0.6335
# [Epoch 100/250] Loss: 0.6349
# [Epoch 101/250] Loss: 0.6347
# [Epoch 102/250] Loss: 0.6343
# [Epoch 103/250] Loss: 0.6358
# [Epoch 104/250] Loss: 0.6339
# [Epoch 105/250] Loss: 0.6338
# [Epoch 106/250] Loss: 0.6337
# [Epoch 107/250] Loss: 0.6335
# [Epoch 108/250] Loss: 0.6347
# [Epoch 109/250] Loss: 0.6340
# [Epoch 110/250] Loss: 0.6335
# [Epoch 111/250] Loss: 0.6352
# [Epoch 112/250] Loss: 0.6349
# [Epoch 113/250] Loss: 0.6335
# [Epoch 114/250] Loss: 0.6337
# [Epoch 115/250] Loss: 0.6353
# [Epoch 116/250] Loss: 0.6346
# [Epoch 117/250] Loss: 0.6349
# [Epoch 118/250] Loss: 0.6338
# [Epoch 119/250] Loss: 0.6335
# [Epoch 120/250] Loss: 0.6338
# [Epoch 121/250] Loss: 0.6334
# [Epoch 122/250] Loss: 0.6334
# [Epoch 123/250] Loss: 0.6338
# [Epoch 124/250] Loss: 0.6344
# [Epoch 125/250] Loss: 0.6348
# [Epoch 126/250] Loss: 0.6344
# [Epoch 127/250] Loss: 0.6332
# [Epoch 128/250] Loss: 0.6353
# [Epoch 129/250] Loss: 0.6344
# [Epoch 130/250] Loss: 0.6329
# [Epoch 131/250] Loss: 0.6336
# [Epoch 132/250] Loss: 0.6343
# [Epoch 133/250] Loss: 0.6341
# [Epoch 134/250] Loss: 0.6352
# [Epoch 135/250] Loss: 0.6340
# [Epoch 136/250] Loss: 0.6352
# [Epoch 137/250] Loss: 0.6333
# [Epoch 138/250] Loss: 0.6337
# [Epoch 139/250] Loss: 0.6343
# [Epoch 140/250] Loss: 0.6341
# [Epoch 141/250] Loss: 0.6331
# [Epoch 142/250] Loss: 0.6340
# [Epoch 143/250] Loss: 0.6340
# [Epoch 144/250] Loss: 0.6343
# [Epoch 145/250] Loss: 0.6337
# [Epoch 146/250] Loss: 0.6356
# [Epoch 147/250] Loss: 0.6342
# [Epoch 148/250] Loss: 0.6330
# [Epoch 149/250] Loss: 0.6347
# [Epoch 150/250] Loss: 0.6346
# [Epoch 151/250] Loss: 0.6345
# [Epoch 152/250] Loss: 0.6348
# [Epoch 153/250] Loss: 0.6340
# [Epoch 154/250] Loss: 0.6338
# [Epoch 155/250] Loss: 0.6349
# [Epoch 156/250] Loss: 0.6341
# [Epoch 157/250] Loss: 0.6346
# [Epoch 158/250] Loss: 0.6338
# [Epoch 159/250] Loss: 0.6338
# [Epoch 160/250] Loss: 0.6348
# [Epoch 161/250] Loss: 0.6337
# [Epoch 162/250] Loss: 0.6342
# [Epoch 163/250] Loss: 0.6337
# [Epoch 164/250] Loss: 0.6338
# [Epoch 165/250] Loss: 0.6343
# [Epoch 166/250] Loss: 0.6343
# [Epoch 167/250] Loss: 0.6344
# [Epoch 168/250] Loss: 0.6342
# [Epoch 169/250] Loss: 0.6348
# [Epoch 170/250] Loss: 0.6362
# [Epoch 171/250] Loss: 0.6342
# [Epoch 172/250] Loss: 0.6343
# [Epoch 173/250] Loss: 0.6344
# [Epoch 174/250] Loss: 0.6356
# [Epoch 175/250] Loss: 0.6347
# [Epoch 176/250] Loss: 0.6334
# [Epoch 177/250] Loss: 0.6348
# [Epoch 178/250] Loss: 0.6345
# [Epoch 179/250] Loss: 0.6326
# [Epoch 180/250] Loss: 0.6338
# [Epoch 181/250] Loss: 0.6341
# [Epoch 182/250] Loss: 0.6347
# [Epoch 183/250] Loss: 0.6341
# [Epoch 184/250] Loss: 0.6358
# [Epoch 185/250] Loss: 0.6346
# [Epoch 186/250] Loss: 0.6338
# [Epoch 187/250] Loss: 0.6337
# [Epoch 188/250] Loss: 0.6341
# [Epoch 189/250] Loss: 0.6342
# [Epoch 190/250] Loss: 0.6351
# [Epoch 191/250] Loss: 0.6340
# [Epoch 192/250] Loss: 0.6349
# [Epoch 193/250] Loss: 0.6350
# [Epoch 194/250] Loss: 0.6350
# [Epoch 195/250] Loss: 0.6351
# [Epoch 196/250] Loss: 0.6347
# [Epoch 197/250] Loss: 0.6345
# [Epoch 198/250] Loss: 0.6337
# [Epoch 199/250] Loss: 0.6354
# [Epoch 200/250] Loss: 0.6331
# [Epoch 201/250] Loss: 0.6348
# [Epoch 202/250] Loss: 0.6340
# [Epoch 203/250] Loss: 0.6340
# [Epoch 204/250] Loss: 0.6332
# [Epoch 205/250] Loss: 0.6334
# [Epoch 206/250] Loss: 0.6351
# [Epoch 207/250] Loss: 0.6356
# [Epoch 208/250] Loss: 0.6351
# [Epoch 209/250] Loss: 0.6360
# [Epoch 210/250] Loss: 0.6351
# [Epoch 211/250] Loss: 0.6332
# [Epoch 212/250] Loss: 0.6328
# [Epoch 213/250] Loss: 0.6347
# [Epoch 214/250] Loss: 0.6339
# [Epoch 215/250] Loss: 0.6334
# [Epoch 216/250] Loss: 0.6350
# [Epoch 217/250] Loss: 0.6340
# [Epoch 218/250] Loss: 0.6349
# [Epoch 219/250] Loss: 0.6343
# [Epoch 220/250] Loss: 0.6349
# [Epoch 221/250] Loss: 0.6332
# [Epoch 222/250] Loss: 0.6348
# [Epoch 223/250] Loss: 0.6337
# [Epoch 224/250] Loss: 0.6345
# [Epoch 225/250] Loss: 0.6352
# [Epoch 226/250] Loss: 0.6339
# [Epoch 227/250] Loss: 0.6340
# [Epoch 228/250] Loss: 0.6348
# [Epoch 229/250] Loss: 0.6338
# [Epoch 230/250] Loss: 0.6351
# [Epoch 231/250] Loss: 0.6333
# [Epoch 232/250] Loss: 0.6344
# [Epoch 233/250] Loss: 0.6348
# [Epoch 234/250] Loss: 0.6338
# [Epoch 235/250] Loss: 0.6354
# [Epoch 236/250] Loss: 0.6352
# [Epoch 237/250] Loss: 0.6324
# [Epoch 238/250] Loss: 0.6344
# [Epoch 239/250] Loss: 0.6352
# [Epoch 240/250] Loss: 0.6341
# [Epoch 241/250] Loss: 0.6341
# [Epoch 242/250] Loss: 0.6357
# [Epoch 243/250] Loss: 0.6343
# [Epoch 244/250] Loss: 0.6343
# [Epoch 245/250] Loss: 0.6357
# [Epoch 246/250] Loss: 0.6341
# [Epoch 247/250] Loss: 0.6339
# [Epoch 248/250] Loss: 0.6333
# [Epoch 249/250] Loss: 0.6356
# [Epoch 250/250] Loss: 0.6340
# [Classifier Epoch 1/250] Loss: 8.4577
# [Classifier Epoch 2/250] Loss: 7.7779
# [Classifier Epoch 3/250] Loss: 6.4597
# [Classifier Epoch 4/250] Loss: 4.9274
# [Classifier Epoch 5/250] Loss: 3.5168
# [Classifier Epoch 6/250] Loss: 2.5325
# [Classifier Epoch 7/250] Loss: 1.9810
# [Classifier Epoch 8/250] Loss: 1.6288
# [Classifier Epoch 9/250] Loss: 1.4227
# [Classifier Epoch 10/250] Loss: 1.2893
# [Classifier Epoch 11/250] Loss: 1.1938
# [Classifier Epoch 12/250] Loss: 1.1065
# [Classifier Epoch 13/250] Loss: 1.0263
# [Classifier Epoch 14/250] Loss: 1.0126
# [Classifier Epoch 15/250] Loss: 0.9065
# [Classifier Epoch 16/250] Loss: 0.8995
# [Classifier Epoch 17/250] Loss: 0.8303
# [Classifier Epoch 18/250] Loss: 0.8536
# [Classifier Epoch 19/250] Loss: 0.8245
# [Classifier Epoch 20/250] Loss: 0.8063
# [Classifier Epoch 21/250] Loss: 0.7352
# [Classifier Epoch 22/250] Loss: 0.7418
# [Classifier Epoch 23/250] Loss: 0.7265
# [Classifier Epoch 24/250] Loss: 0.7154
# [Classifier Epoch 25/250] Loss: 0.7219
# [Classifier Epoch 26/250] Loss: 0.6438
# [Classifier Epoch 27/250] Loss: 0.6436
# [Classifier Epoch 28/250] Loss: 0.6289
# [Classifier Epoch 29/250] Loss: 0.6477
# [Classifier Epoch 30/250] Loss: 0.6044
# [Classifier Epoch 31/250] Loss: 0.6002
# [Classifier Epoch 32/250] Loss: 0.6131
# [Classifier Epoch 33/250] Loss: 0.5430
# [Classifier Epoch 34/250] Loss: 0.5558
# [Classifier Epoch 35/250] Loss: 0.5867
# [Classifier Epoch 36/250] Loss: 0.5466
# [Classifier Epoch 37/250] Loss: 0.5456
# [Classifier Epoch 38/250] Loss: 0.5025
# [Classifier Epoch 39/250] Loss: 0.5337
# [Classifier Epoch 40/250] Loss: 0.5178
# [Classifier Epoch 41/250] Loss: 0.4827
# [Classifier Epoch 42/250] Loss: 0.4924
# [Classifier Epoch 43/250] Loss: 0.4867
# [Classifier Epoch 44/250] Loss: 0.4643
# [Classifier Epoch 45/250] Loss: 0.5231
# [Classifier Epoch 46/250] Loss: 0.4803
# [Classifier Epoch 47/250] Loss: 0.5449
# [Classifier Epoch 48/250] Loss: 0.4928
# [Classifier Epoch 49/250] Loss: 0.4801
# [Classifier Epoch 50/250] Loss: 0.4668
# [Classifier Epoch 51/250] Loss: 0.4626
# [Classifier Epoch 52/250] Loss: 0.4706
# [Classifier Epoch 53/250] Loss: 0.4843
# [Classifier Epoch 54/250] Loss: 0.4538
# [Classifier Epoch 55/250] Loss: 0.4775
# [Classifier Epoch 56/250] Loss: 0.4789
# [Classifier Epoch 57/250] Loss: 0.4761
# [Classifier Epoch 58/250] Loss: 0.4734
# [Classifier Epoch 59/250] Loss: 0.4568
# [Classifier Epoch 60/250] Loss: 0.4656
# [Classifier Epoch 61/250] Loss: 0.4384
# [Classifier Epoch 62/250] Loss: 0.4492
# [Classifier Epoch 63/250] Loss: 0.4202
# [Classifier Epoch 64/250] Loss: 0.4537
# [Classifier Epoch 65/250] Loss: 0.4423
# [Classifier Epoch 66/250] Loss: 0.4145
# [Classifier Epoch 67/250] Loss: 0.4173
# [Classifier Epoch 68/250] Loss: 0.3983
# [Classifier Epoch 69/250] Loss: 0.4108
# [Classifier Epoch 70/250] Loss: 0.4481
# [Classifier Epoch 71/250] Loss: 0.4194
# [Classifier Epoch 72/250] Loss: 0.4251
# [Classifier Epoch 73/250] Loss: 0.4025
# [Classifier Epoch 74/250] Loss: 0.4388
# [Classifier Epoch 75/250] Loss: 0.4298
# [Classifier Epoch 76/250] Loss: 0.4376
# [Classifier Epoch 77/250] Loss: 0.4386
# [Classifier Epoch 78/250] Loss: 0.4635
# [Classifier Epoch 79/250] Loss: 0.4045
# [Classifier Epoch 80/250] Loss: 0.3825
# [Classifier Epoch 81/250] Loss: 0.4008
# [Classifier Epoch 82/250] Loss: 0.3929
# [Classifier Epoch 83/250] Loss: 0.3897
# [Classifier Epoch 84/250] Loss: 0.4053
# [Classifier Epoch 85/250] Loss: 0.4050
# [Classifier Epoch 86/250] Loss: 0.3658
# [Classifier Epoch 87/250] Loss: 0.3756
# [Classifier Epoch 88/250] Loss: 0.4183
# [Classifier Epoch 89/250] Loss: 0.3512
# [Classifier Epoch 90/250] Loss: 0.3779
# [Classifier Epoch 91/250] Loss: 0.3679
# [Classifier Epoch 92/250] Loss: 0.3816
# [Classifier Epoch 93/250] Loss: 0.4018
# [Classifier Epoch 94/250] Loss: 0.3792
# [Classifier Epoch 95/250] Loss: 0.4143
# [Classifier Epoch 96/250] Loss: 0.3822
# [Classifier Epoch 97/250] Loss: 0.3482
# [Classifier Epoch 98/250] Loss: 0.3981
# [Classifier Epoch 99/250] Loss: 0.3399
# [Classifier Epoch 100/250] Loss: 0.3738
# [Classifier Epoch 101/250] Loss: 0.3593
# [Classifier Epoch 102/250] Loss: 0.3664
# [Classifier Epoch 103/250] Loss: 0.3730
# [Classifier Epoch 104/250] Loss: 0.3927
# [Classifier Epoch 105/250] Loss: 0.3769
# [Classifier Epoch 106/250] Loss: 0.3574
# [Classifier Epoch 107/250] Loss: 0.3626
# [Classifier Epoch 108/250] Loss: 0.3672
# [Classifier Epoch 109/250] Loss: 0.3858
# [Classifier Epoch 110/250] Loss: 0.3522
# [Classifier Epoch 111/250] Loss: 0.3679
# [Classifier Epoch 112/250] Loss: 0.3577
# [Classifier Epoch 113/250] Loss: 0.3760
# [Classifier Epoch 114/250] Loss: 0.3415
# [Classifier Epoch 115/250] Loss: 0.3578
# [Classifier Epoch 116/250] Loss: 0.3471
# [Classifier Epoch 117/250] Loss: 0.3425
# [Classifier Epoch 118/250] Loss: 0.3556
# [Classifier Epoch 119/250] Loss: 0.3570
# [Classifier Epoch 120/250] Loss: 0.3410
# [Classifier Epoch 121/250] Loss: 0.3528
# [Classifier Epoch 122/250] Loss: 0.3506
# [Classifier Epoch 123/250] Loss: 0.3806
# [Classifier Epoch 124/250] Loss: 0.3632
# [Classifier Epoch 125/250] Loss: 0.3336
# [Classifier Epoch 126/250] Loss: 0.3575
# [Classifier Epoch 127/250] Loss: 0.3077
# [Classifier Epoch 128/250] Loss: 0.3414
# [Classifier Epoch 129/250] Loss: 0.3644
# [Classifier Epoch 130/250] Loss: 0.3395
# [Classifier Epoch 131/250] Loss: 0.3134
# [Classifier Epoch 132/250] Loss: 0.3135
# [Classifier Epoch 133/250] Loss: 0.3151
# [Classifier Epoch 134/250] Loss: 0.3653
# [Classifier Epoch 135/250] Loss: 0.3387
# [Classifier Epoch 136/250] Loss: 0.3548
# [Classifier Epoch 137/250] Loss: 0.3228
# [Classifier Epoch 138/250] Loss: 0.3384
# [Classifier Epoch 139/250] Loss: 0.3100
# [Classifier Epoch 140/250] Loss: 0.3336
# [Classifier Epoch 141/250] Loss: 0.3364
# [Classifier Epoch 142/250] Loss: 0.3208
# [Classifier Epoch 143/250] Loss: 0.3523
# [Classifier Epoch 144/250] Loss: 0.3212
# [Classifier Epoch 145/250] Loss: 0.3161
# [Classifier Epoch 146/250] Loss: 0.3256
# [Classifier Epoch 147/250] Loss: 0.3453
# [Classifier Epoch 148/250] Loss: 0.3264
# [Classifier Epoch 149/250] Loss: 0.3244
# [Classifier Epoch 150/250] Loss: 0.3454
# [Classifier Epoch 151/250] Loss: 0.3490
# [Classifier Epoch 152/250] Loss: 0.3455
# [Classifier Epoch 153/250] Loss: 0.3047
# [Classifier Epoch 154/250] Loss: 0.3130
# [Classifier Epoch 155/250] Loss: 0.3136
# [Classifier Epoch 156/250] Loss: 0.3092
# [Classifier Epoch 157/250] Loss: 0.3236
# [Classifier Epoch 158/250] Loss: 0.3227
# [Classifier Epoch 159/250] Loss: 0.3286
# [Classifier Epoch 160/250] Loss: 0.3125
# [Classifier Epoch 161/250] Loss: 0.3165
# [Classifier Epoch 162/250] Loss: 0.3536
# [Classifier Epoch 163/250] Loss: 0.3288
# [Classifier Epoch 164/250] Loss: 0.3213
# [Classifier Epoch 165/250] Loss: 0.2997
# [Classifier Epoch 166/250] Loss: 0.3044
# [Classifier Epoch 167/250] Loss: 0.3273
# [Classifier Epoch 168/250] Loss: 0.3161
# [Classifier Epoch 169/250] Loss: 0.3113
# [Classifier Epoch 170/250] Loss: 0.3082
# [Classifier Epoch 171/250] Loss: 0.3155
# [Classifier Epoch 172/250] Loss: 0.2962
# [Classifier Epoch 173/250] Loss: 0.3485
# [Classifier Epoch 174/250] Loss: 0.3064
# [Classifier Epoch 175/250] Loss: 0.3182
# [Classifier Epoch 176/250] Loss: 0.3076
# [Classifier Epoch 177/250] Loss: 0.3246
# [Classifier Epoch 178/250] Loss: 0.3449
# [Classifier Epoch 179/250] Loss: 0.3306
# [Classifier Epoch 180/250] Loss: 0.3200
# [Classifier Epoch 181/250] Loss: 0.2884
# [Classifier Epoch 182/250] Loss: 0.2986
# [Classifier Epoch 183/250] Loss: 0.3140
# [Classifier Epoch 184/250] Loss: 0.3029
# [Classifier Epoch 185/250] Loss: 0.3498
# [Classifier Epoch 186/250] Loss: 0.3466
# [Classifier Epoch 187/250] Loss: 0.3099
# [Classifier Epoch 188/250] Loss: 0.2955
# [Classifier Epoch 189/250] Loss: 0.3115
# [Classifier Epoch 190/250] Loss: 0.2958
# [Classifier Epoch 191/250] Loss: 0.3222
# [Classifier Epoch 192/250] Loss: 0.3071
# [Classifier Epoch 193/250] Loss: 0.2917
# [Classifier Epoch 194/250] Loss: 0.3046
# [Classifier Epoch 195/250] Loss: 0.3156
# [Classifier Epoch 196/250] Loss: 0.2887
# [Classifier Epoch 197/250] Loss: 0.3279
# [Classifier Epoch 198/250] Loss: 0.3165
# [Classifier Epoch 199/250] Loss: 0.3106
# [Classifier Epoch 200/250] Loss: 0.2936
# [Classifier Epoch 201/250] Loss: 0.2980
# [Classifier Epoch 202/250] Loss: 0.2990
# [Classifier Epoch 203/250] Loss: 0.3135
# [Classifier Epoch 204/250] Loss: 0.3002
# [Classifier Epoch 205/250] Loss: 0.3191
# [Classifier Epoch 206/250] Loss: 0.3225
# [Classifier Epoch 207/250] Loss: 0.3522
# [Classifier Epoch 208/250] Loss: 0.2961
# [Classifier Epoch 209/250] Loss: 0.3037
# [Classifier Epoch 210/250] Loss: 0.2984
# [Classifier Epoch 211/250] Loss: 0.2994
# [Classifier Epoch 212/250] Loss: 0.3046
# [Classifier Epoch 213/250] Loss: 0.2993
# [Classifier Epoch 214/250] Loss: 0.2752
# [Classifier Epoch 215/250] Loss: 0.3123
# [Classifier Epoch 216/250] Loss: 0.3338
# [Classifier Epoch 217/250] Loss: 0.3087
# [Classifier Epoch 218/250] Loss: 0.2937
# [Classifier Epoch 219/250] Loss: 0.2962
# [Classifier Epoch 220/250] Loss: 0.3224
# [Classifier Epoch 221/250] Loss: 0.3403
# [Classifier Epoch 222/250] Loss: 0.3079
# [Classifier Epoch 223/250] Loss: 0.2979
# [Classifier Epoch 224/250] Loss: 0.2893
# [Classifier Epoch 225/250] Loss: 0.2563
# [Classifier Epoch 226/250] Loss: 0.2977
# [Classifier Epoch 227/250] Loss: 0.2889
# [Classifier Epoch 228/250] Loss: 0.3081
# [Classifier Epoch 229/250] Loss: 0.3239
# [Classifier Epoch 230/250] Loss: 0.2811
# [Classifier Epoch 231/250] Loss: 0.2761
# [Classifier Epoch 232/250] Loss: 0.2807
# [Classifier Epoch 233/250] Loss: 0.2846
# [Classifier Epoch 234/250] Loss: 0.2952
# [Classifier Epoch 235/250] Loss: 0.2891
# [Classifier Epoch 236/250] Loss: 0.3227
# [Classifier Epoch 237/250] Loss: 0.2752
# [Classifier Epoch 238/250] Loss: 0.2758
# [Classifier Epoch 239/250] Loss: 0.2543
# [Classifier Epoch 240/250] Loss: 0.3176
# [Classifier Epoch 241/250] Loss: 0.2874
# [Classifier Epoch 242/250] Loss: 0.3041
# [Classifier Epoch 243/250] Loss: 0.2999
# [Classifier Epoch 244/250] Loss: 0.2652
# [Classifier Epoch 245/250] Loss: 0.2812
# [Classifier Epoch 246/250] Loss: 0.2620
# [Classifier Epoch 247/250] Loss: 0.3289
# [Classifier Epoch 248/250] Loss: 0.2799
# [Classifier Epoch 249/250] Loss: 0.2621
# [Classifier Epoch 250/250] Loss: 0.3030
# Building Recs: 100%|███████████████████████████████████████████████████████████████| 5148/5148 [01:35<00:00, 53.88it/s]

# %%
def build_recommendations(embeddings, ids, infos, topK=10):
    recommendations = []
    N = len(embeddings)

    for i in tqdm(range(N), desc="Building Recommendations"):
        vec_i = embeddings[i]
        sims = [
            {"source_id": ids[i], "target_id": ids[j], "similarity": cosine_similarity(vec_i, embeddings[j])}
            for j in range(N) if i != j
        ]
        top_k_recs = sorted(sims, key=lambda x: x["similarity"], reverse=True)[:topK]
        recommendations.extend(top_k_recs)

    return pd.DataFrame(recommendations)

full_dataset = Music4AllOnionDataset(fused_df_normalized)
embeddings = compute_all_embeddings(full_dataset, mkgcn_model, device=device)
ids = fused_df_normalized.index.tolist()
recommendations = build_recommendations(embeddings, ids, fused_df_normalized, topK=100)
recommendations.to_csv("recs_mkgcn_10.csv", index=False)
# Out:
# Building Recommendations: 100%|████████████████████████████████████████████████████| 5148/5148 [01:45<00:00, 48.79it/s]
